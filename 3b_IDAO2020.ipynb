# %% [markdown]
# # Startegi : Using chain rule

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
import time, copy

# %% [raw]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
path='data/train.csv'

# %%
df=pd.read_csv(path, index_col=0)
df=df[['x','y','z','x_sim','y_sim','z_sim']]
# df=df.drop('epoch', axis=1)
df.head()
# Out:
#                x             y             z         x_sim         y_sim  \
# id
# 0   -8855.823863  13117.780146 -20728.353233  -8843.131454  13138.221690
# 1  -10567.672384   1619.746066 -24451.813271 -10555.500066   1649.289367
# 2  -10578.684043 -10180.467460 -24238.280949 -10571.858472 -10145.939908
# 3   -9148.251857 -20651.437460 -20720.381279  -9149.620794 -20618.200201
# 4   -6719.092336 -28929.061629 -14938.907967  -6729.358857 -28902.271436
#
#            z_sim
# id
# 0  -20741.615306
# 1  -24473.089556
# 2  -24271.169776
# 3  -20765.019094
# 4  -14992.399986

# %%
mydata=df.copy()

# %%
mydata.isna().sum()
# Out:
# x        0
# y        0
# z        0
# x_sim    0
# y_sim    0
# z_sim    0
# dtype: int64

# %%
mydata = mydata.dropna()
mydata.shape
# Out:
# (649912, 6)

# %%
train_mydata = mydata.sample(frac=0.8,random_state=0)
test_mydata = mydata.drop(train_mydata.index)
test_mydata.head()
# Out:
#                x             y             z         x_sim         y_sim  \
# id
# 1  -10567.672384   1619.746066 -24451.813271 -10555.500066   1649.289367
# 4   -6719.092336 -28929.061629 -14938.907967  -6729.358857 -28902.271436
# 15  17281.246143  -2011.121378  39970.739873  17241.395285  -2016.770194
# 22  -1447.724638  28032.228987  -3918.192838  -1461.093061  28026.085525
# 26 -10583.521489 -10145.003880 -24243.775722 -10574.016380 -10147.909472
#
#            z_sim
# id
# 1  -24473.089556
# 4  -14992.399986
# 15  39958.759155
# 22  -3959.767549
# 26 -24270.149411

# %%
#a=train_mydata.shape
#b=test_mydata.shape
#print(a,b)
print(train_mydata.shape, test_mydata.shape)
train_mydata.head()
# Out:
# (519930, 6) (129982, 6)
#                     x             y             z         x_sim         y_sim  \
# id
# 162906  -22445.306373   5848.139687    805.906588 -21786.206588   7375.036638
# 123662   -9086.781838   7654.307240  -6721.299832  -9545.479053   7482.025507
# 901720  -33475.100342 -37591.455624  -3269.507831 -33263.131053 -37783.198553
# 308669   11617.034853   2343.826977  -1821.565305  10718.558812   5174.769686
# 1154759  25113.931453   -473.679010  41867.498593  19229.123354  12147.342145
#
#                 z_sim
# id
# 162906     391.178832
# 123662   -6387.708079
# 901720   -3617.165346
# 308669   -1069.308627
# 1154759  31835.248429

# %%
label=['Vx','Vy','Vz','x','y','z'][3:]
train_stats = train_mydata.describe()
for i in label:
  train_stats.pop(i)
train_stats = train_stats.transpose()
train_stats
# Out:
#           count        mean           std            min           25%  \
# x_sim  519930.0 -941.331006  25387.037253 -255037.952966 -13139.771199
# y_sim  519930.0  319.853163  25603.245579 -281784.430040 -11758.892200
# z_sim  519930.0  -77.075471  20670.833347 -180250.922287  -7963.461284
#
#               50%           75%            max
# x_sim -612.877803  11194.372299  200961.158000
# y_sim  501.609913  12558.620911  209619.553857
# z_sim   57.093264   8253.028193  198526.091552

# %%
train_labels = train_mydata[label]
test_labels = test_mydata[label]

# %%
print(train_labels.head())
print(test_labels.head())
# Out:
#                     x             y             z
# id
# 162906  -22445.306373   5848.139687    805.906588
# 123662   -9086.781838   7654.307240  -6721.299832
# 901720  -33475.100342 -37591.455624  -3269.507831
# 308669   11617.034853   2343.826977  -1821.565305
# 1154759  25113.931453   -473.679010  41867.498593
#                x             y             z
# id
# 1  -10567.672384   1619.746066 -24451.813271
# 4   -6719.092336 -28929.061629 -14938.907967
# 15  17281.246143  -2011.121378  39970.739873
# 22  -1447.724638  28032.228987  -3918.192838
# 26 -10583.521489 -10145.003880 -24243.775722

# %%
def norm(x):
  try:
    return (x - train_stats['mean']) / train_stats['std']
  except:
    print(x)

# %%
normed_train_data = norm(train_mydata.drop(label, axis=1))
normed_test_data = norm(test_mydata.drop(label, axis=1))

# %%
a=normed_test_data.describe()
a.transpose()
# Out:
#           count      mean       std        min       25%       50%       75%  \
# x_sim  129982.0 -0.001650  0.997447 -10.002493 -0.483600  0.011332  0.477304
# y_sim  129982.0  0.000919  1.000829 -11.059974 -0.467484  0.011119  0.476295
# z_sim  129982.0 -0.000651  0.999315  -8.628536 -0.380103  0.006436  0.399140
#
#             max
# x_sim  7.940276
# y_sim  8.154777
# z_sim  9.581585

# %%
normed_train_data.head()
# Out:
#             x_sim     y_sim     z_sim
# id
# 162906  -0.821083  0.275558  0.022653
# 123662  -0.338919  0.279737 -0.305292
# 901720  -1.273162 -1.488212 -0.171260
# 308669   0.459285  0.189621 -0.048002
# 1154759  0.794518  0.461953  1.543833

# %%
toc=time.time()
tic=time.time()
print('%f'%(tic-toc))
# Out:
# 0.000100

# %%
normed_train_data1=normed_train_data.copy()
normed_test_data1=normed_test_data.copy()

# %%
for i in label:
    print(normed_train_data.columns)
    toc=time.time()
    reg = LinearRegression()
    reg.fit(normed_train_data, train_labels[i])
    tic=time.time()
    print( '%f s'%(tic-toc))
    print('score for label train %s : %f'%(i,reg.score(normed_train_data, train_labels[i])))
    print('score for label test %s : %f'%(i,reg.score(normed_test_data, test_labels[i])))
    y_train_pred=reg.predict(normed_train_data)
    y_test_pred=reg.predict(normed_test_data)
    train_mydata[i+'_pred']=y_train_pred
    test_mydata[i+'_pred']=y_test_pred
    normed_train_data[i+'_pred']=y_train_pred
    normed_test_data[i+'_pred']=y_test_pred
# Out:
# Index(['x_sim', 'y_sim', 'z_sim'], dtype='object')
# 0.042940 s
# score for label train x : 0.920970
# score for label test x : 0.922387
# Index(['x_sim', 'y_sim', 'z_sim', 'x_pred'], dtype='object')
# 0.073998 s
# score for label train y : 0.922276
# score for label test y : 0.921566
# Index(['x_sim', 'y_sim', 'z_sim', 'x_pred', 'y_pred'], dtype='object')
# 0.049057 s
# score for label train z : 0.918310
# score for label test z : 0.920634

# %%
test_mydata['index']=[i for i in range(len(test_mydata))]
test_mydata
# Out:
#                     x             y             z         x_sim         y_sim  \
# id
# 1       -10567.672384   1619.746066 -24451.813271 -10555.500066   1649.289367
# 4        -6719.092336 -28929.061629 -14938.907967  -6729.358857 -28902.271436
# 15       17281.246143  -2011.121378  39970.739873  17241.395285  -2016.770194
# 271351   -7694.049850  -19934.431291   6224.472989  -6981.497857
# 593035   30349.573681  -42985.058946   1710.892128  29762.063693
# 879339  -33813.138578   -1847.310018 -29762.051118 -32764.137765
#
#                 z_pred   index
# id
# 162906      361.805869       0
# 123662    -6082.855952       1
# 901720    -3922.044969       2
# 308669     -929.974400       3
# 1154759   30683.235832       4
# 744829    34862.413157       5
# 55680      -985.918492       6
# 328827    18629.616590       7
# 947736     4004.543063       8
# 206257   -11787.225012       9
# 733904     2301.118786      10
# 830839    -8453.050324      11
# 1209421     940.331938      12
# 654930   -14450.670661      13
# 1037247  -45627.275130      14
# 85528      5580.686276      15
# 412285   -16328.574277      16
# 378146     5668.130078      17
# 582101    10840.524543      18
# 1107435    2631.267214      19
# 572829    -9585.710862      20
# 696218    -7601.544348      21
# 468052   -30443.224116      22
# 185858   -16796.256779      23
# 832177    -9364.455694      24
# 320902   -26957.181403      25
# 1093858   -2343.483994      26
# 647486     3478.212780      27
# 1215400   15550.807546      28
# 308985     2961.409351      29
# ...                ...     ...
# 1205932   14317.261836  519900
# 197886    -7509.428677  519901
# 115730     3308.887406  519902
# 438728     2693.399860  519903
# 135769   -22046.016289  519904
# 730845   -41836.472870  519905
# 1230457    1078.925698  519906
# 1140070   -7674.371634  519907
# 322331   -10269.370394  519908
# 307743     3078.014442  519909
# 331980    10564.019255  519910
# 920617      312.972539  519911
# 922695      402.125618  519912
# 607558    -2504.965162  519913
# 913988   122678.662318  519914
# 574621     1261.937156  519915
# 608303    -1724.676337  519916
# 91813      6779.026787  519917
# 48280    -10944.041653  519918
# 91650      3457.883070  519919
# 261149   -14066.760948  519920
# 611308     2463.043130  519921
# 1220980   30192.628962  519922
# 75443     -9632.839307  519923
# 263080    14063.742386  519924
# 294580     2182.343041  519925
# 491941     1163.390671  519926
# 271351   -19131.802281  519927
# 593035   -40891.534859  519928
# 879339    -2184.751490  519929
#
# [519930 rows x 10 columns]

# %%
from matplotlib.pyplot import figure

# %%
# figure(num=None, figsize=(20, 15), dpi=80, facecolor='w', edgecolor='k')
fig, axs = plt.subplots(3, 3, figsize=(30, 15))
c=0
for i in label:
    axs[c, 0].plot('index',i+'_pred', data=test_mydata.iloc[0:100,:])
    axs[c, 0].plot('index',i, data=test_mydata.iloc[0:100,:])
    axs[c, 0].set_title('Prediction vs Real')
    axs[c, 0].legend()
    axs[c, 1].plot('index',i+'_sim', data=test_mydata.iloc[0:100,:], color='red')
    axs[c, 1].plot('index',i, data=test_mydata.iloc[0:100,:])
    axs[c, 1].set_title('Simulation vs Real')
    axs[c, 1].legend()
    axs[c, 2].plot('index',i+'_pred', data=test_mydata.iloc[0:100,:],  color='green')
    axs[c, 2].plot('index',i+'_sim', data=test_mydata.iloc[0:100,:])
    axs[c, 2].set_title('Prediction vs Simulationl')
    axs[c, 2].legend()  
    c+=1

#     for ax in axs.flat:
#         ax.set(xlabel='x-label', ylabel='y-label')

#     # Hide x labels and tick labels for top plots and y ticks for right plots.
#     for ax in axs.flat:
#         ax.label_outer()
# Out:
# /Users/bytedance-it138302/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Second argument 'x' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#
# /Users/bytedance-it138302/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: Second argument 'x' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/bytedance-it138302/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#
# /Users/bytedance-it138302/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   # Remove the CWD from sys.path while we load stuff.

# %%
test_mydata.head()
# Out:
#                x             y             z         x_sim         y_sim  \
# id
# 1  -10567.672384   1619.746066 -24451.813271 -10555.500066   1649.289367
# 4   -6719.092336 -28929.061629 -14938.907967  -6729.358857 -28902.271436
# 15  17281.246143  -2011.121378  39970.739873  17241.395285  -2016.770194
# 22  -1447.724638  28032.228987  -3918.192838  -1461.093061  28026.085525
# 26 -10583.521489 -10145.003880 -24243.775722 -10574.016380 -10147.909472
#
#            z_sim        x_pred        y_pred        z_pred  index
# id
# 1  -24473.089556  -9968.351935   1825.372065 -23461.885425      0
# 4  -14992.399986  -5974.950104 -27584.655337 -14636.076588      1
# 15  39958.759155  16523.236777  -1997.123319  38331.418185      2
# 22  -3959.767549  -1619.389094  27083.613896  -3543.884465      3
# 26 -24270.149411  -9849.778000  -9515.035777 -23371.972827      4

# %%
def smape(satellite_predicted_values, satellite_true_values):
    return np.mean(np.abs((satellite_predicted_values - satellite_true_values)/(np.abs(satellite_predicted_values) + np.abs(satellite_true_values))))

# %%
for i in label:
    print('smape real vs sim : %f, smape real vs prediction : %f ' %(smape(test_mydata[i], test_mydata[i+'_sim']), smape(test_mydata[i], test_mydata[i+'_pred'])))
# Out:
# smape real vs sim : 0.182732, smape real vs prediction : 0.190678
# smape real vs sim : 0.186034, smape real vs prediction : 0.195309
# smape real vs sim : 0.183391, smape real vs prediction : 0.200647

# %%
for i in ['_sim', '_pred']:
    real=np.array(test_mydata[label])
    compare=np.array(test_mydata[[j+i for j in label]])
    print('smape real vs %s : %f' %(i, smape(real, compare)))
# Out:
# smape real vs _sim : 0.184052
# smape real vs _pred : 0.195545

# %%
test_mydata.head()
# Out:
#                x             y             z         x_sim         y_sim  \
# id
# 1  -10567.672384   1619.746066 -24451.813271 -10555.500066   1649.289367
# 4   -6719.092336 -28929.061629 -14938.907967  -6729.358857 -28902.271436
# 15  17281.246143  -2011.121378  39970.739873  17241.395285  -2016.770194
# 22  -1447.724638  28032.228987  -3918.192838  -1461.093061  28026.085525
# 26 -10583.521489 -10145.003880 -24243.775722 -10574.016380 -10147.909472
#
#            z_sim  x_predLinearRegression  x_predRandomForestRegressor  \
# id
# 1  -24473.089556            -9968.351935                -12991.864557
# 4  -14992.399986            -5974.950104                -12991.864557
# 15  39958.759155            16523.236777                  9197.647744
# 22  -3959.767549            -1619.389094                  6966.146946
# 26 -24270.149411            -9849.778000                -12991.864557
#
#     y_predLinearRegression  y_predRandomForestRegressor  \
# id
# 1              1825.372065                 11482.729351
# 4            -27584.655337                -11078.599856
# 15            -1997.123319                -11078.599856
# 22            27083.613896                 11482.729351
# 26            -9515.035777                -11078.599856
#
#     z_predLinearRegression  z_predRandomForestRegressor  index
# id
# 1            -23461.885425                -17970.551746      0
# 4            -14636.076585                -17970.551746      1
# 15            38331.418186                 36140.832208      2
# 22            -3543.884468                  2919.116524      3
# 26           -23371.972826                -17970.551746      4
