# %% [markdown]
# # Startegi : Using each label using neural network(regression) and choose predictor by correlation

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor
# Out:
# Using TensorFlow backend.

# %% [raw]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
path='data/train.csv'
list_variable={'x':['sat_id', 'x_sim', 'y_sim', 'Vz_sim'], 'y':['sat_id','x_sim','y_sim','Vx_sim'], 'z':['sat_id','y_sim','z_sim','Vy_sim']}

# %%
df=pd.read_csv(path, index_col=0)
# df=df[['x','y','z','x_sim','y_sim','z_sim']]
df=df.drop('epoch', axis=1)
df.head()
# Out:
#     sat_id             x             y             z        Vx        Vy  \
# id
# 0        0  -8855.823863  13117.780146 -20728.353233 -0.908303 -3.808436
# 1        0 -10567.672384   1619.746066 -24451.813271 -0.302590 -4.272617
# 2        0 -10578.684043 -10180.467460 -24238.280949  0.277435 -4.047522
# 3        0  -9148.251857 -20651.437460 -20720.381279  0.715600 -3.373762
# 4        0  -6719.092336 -28929.061629 -14938.907967  0.992507 -2.519732
#
#           Vz         x_sim         y_sim         z_sim    Vx_sim    Vy_sim  \
# id
# 0  -2.022083  -8843.131454  13138.221690 -20741.615306 -0.907527 -3.804930
# 1  -0.612796 -10555.500066   1649.289367 -24473.089556 -0.303704 -4.269816
# 2   0.723155 -10571.858472 -10145.939908 -24271.169776  0.274880 -4.046788
# 3   1.722115  -9149.620794 -20618.200201 -20765.019094  0.712437 -3.375202
# 4   2.344703  -6729.358857 -28902.271436 -14992.399986  0.989382 -2.522618
#
#       Vz_sim
# id
# 0  -2.024133
# 1  -0.616468
# 2   0.718768
# 3   1.718306
# 4   2.342237

# %%
mydata=df.copy()

# %%
mydata.isna().sum()
# Out:
# sat_id    0
# x         0
# y         0
# z         0
# Vx        0
# Vy        0
# Vz        0
# x_sim     0
# y_sim     0
# z_sim     0
# Vx_sim    0
# Vy_sim    0
# Vz_sim    0
# dtype: int64

# %%
mydata = mydata.dropna()
mydata.shape
# Out:
# (649912, 13)

# %%
train_mydata = mydata.sample(frac=0.8,random_state=0)
test_mydata = mydata.drop(train_mydata.index)
test_mydata.head()
# Out:
#     sat_id             x             y             z        Vx        Vy  \
# id
# 1        0 -10567.672384   1619.746066 -24451.813271 -0.302590 -4.272617
# 4        0  -6719.092336 -28929.061629 -14938.907967  0.992507 -2.519732
# 15       0  17281.246143  -2011.121378  39970.739873 -0.104355  2.653343
# 22       0  -1447.724638  28032.228987  -3918.192838 -1.560091 -1.321435
# 26       0 -10583.521489 -10145.003880 -24243.775722  0.275212 -4.049127
#
#           Vz         x_sim         y_sim         z_sim    Vx_sim    Vy_sim  \
# id
# 1  -0.612796 -10555.500066   1649.289367 -24473.089556 -0.303704 -4.269816
# 4   2.344703  -6729.358857 -28902.271436 -14992.399986  0.989382 -2.522618
# 15 -0.295245  17241.395285  -2016.770194  39958.759155 -0.103839  2.655338
# 22 -3.577772  -1461.093061  28026.085525  -3959.767549 -1.557072 -1.324386
# 26  0.719273 -10574.016380 -10147.909472 -24270.149411  0.274385 -4.046727
#
#       Vz_sim
# id
# 1  -0.616468
# 4   2.342237
# 15 -0.294835
# 22 -3.577769
# 26  0.718858

# %%
#a=train_mydata.shape
#b=test_mydata.shape
#print(a,b)
print(train_mydata.shape, test_mydata.shape)
train_mydata.head()
# Out:
# (519930, 13) (129982, 13)
#          sat_id             x             y             z        Vx        Vy  \
# id
# 162906       81 -22445.306373   5848.139687    805.906588 -1.295831 -3.424371
# 123662       60  -9086.781838   7654.307240  -6721.299832  4.189223  1.357308
# 901720      449 -33475.100342 -37591.455624  -3269.507831  0.115463 -1.791145
# 308669      166  11617.034853   2343.826977  -1821.565305 -1.136521  5.835368
# 1154759     560  25113.931453   -473.679010  41867.498593 -0.849950  2.496597
#
#                Vz         x_sim         y_sim         z_sim    Vx_sim  \
# id
# 162906   0.920461 -21786.206588   7375.036638    391.178832 -1.616993
# 123662  -2.946352  -9545.479053   7482.025507  -6387.708079  4.036478
# 901720  -1.901966 -33263.131053 -37783.198553  -3617.165346  0.130353
# 308669   1.405297  10718.558812   5174.769686  -1069.308627 -2.446951
# 1154759 -1.506792  19229.123354  12147.342145  31835.248429 -1.395221
#
#            Vy_sim    Vz_sim
# id
# 162906  -3.329732  0.928155
# 123662   1.482306 -3.057046
# 901720  -1.782338 -1.906924
# 308669   5.391866  1.577077
# 1154759  2.336560 -2.422340

# %%
label=['Vx','Vy','Vz','x','y','z'][3:]
train_stats = train_mydata.describe()
for i in label:
  train_stats.pop(i)
train_stats = train_stats.transpose()
train_stats
# Out:
#            count        mean           std            min           25%  \
# sat_id  519930.0  308.718101    171.427627       0.000000    166.000000
# Vx      519930.0   -0.001039      2.638712      -8.286673     -1.894451
# Vy      519930.0   -0.001091      2.596198      -8.231654     -1.876317
# Vz      519930.0   -0.000599      2.116234      -9.371164     -1.256092
# x_sim   519930.0 -941.331006  25387.037253 -255037.952966 -13139.771199
# y_sim   519930.0  319.853163  25603.245579 -281784.430040 -11758.892200
# z_sim   519930.0  -77.075471  20670.833347 -180250.922287  -7963.461284
# Vx_sim  519930.0   -0.001115      2.636436      -8.240694     -1.896241
# Vy_sim  519930.0   -0.002132      2.599643      -8.348831     -1.878077
# Vz_sim  519930.0   -0.000170      2.114104      -7.671565     -1.247046
#
#                50%           75%            max
# sat_id  312.000000    461.000000     599.000000
# Vx        0.017755      1.958741       8.149559
# Vy       -0.053612      1.840252      12.308450
# Vz        0.008927      1.233894       8.644558
# x_sim  -612.877803  11194.372299  200961.158000
# y_sim   501.609913  12558.620911  209619.553857
# z_sim    57.093264   8253.028193  198526.091552
# Vx_sim    0.019026      1.954861       7.431844
# Vy_sim   -0.018243      1.857399       8.021438
# Vz_sim    0.011688      1.235497       8.644165

# %%
train_labels = train_mydata[label]
test_labels = test_mydata[label]

# %%
print(train_labels.head(), test_labels.head())
# Out:
#                     x             y             z
# id
# 162906  -22445.306373   5848.139687    805.906588
# 123662   -9086.781838   7654.307240  -6721.299832
# 901720  -33475.100342 -37591.455624  -3269.507831
# 308669   11617.034853   2343.826977  -1821.565305
# 1154759  25113.931453   -473.679010  41867.498593                x             y             z
# id
# 1  -10567.672384   1619.746066 -24451.813271
# 4   -6719.092336 -28929.061629 -14938.907967
# 15  17281.246143  -2011.121378  39970.739873
# 22  -1447.724638  28032.228987  -3918.192838
# 26 -10583.521489 -10145.003880 -24243.775722

# %%
def norm(x):
  try:
    return (x - train_stats['mean']) / train_stats['std']
  except:
    print(x)

# %%
normed_train_data = norm(train_mydata.drop(label, axis=1))
normed_test_data = norm(test_mydata.drop(label, axis=1))

# %%
a=normed_test_data.describe()
a.transpose()
# Out:
#            count      mean       std        min       25%       50%       75%  \
# sat_id  129982.0  0.000357  1.001616  -1.800866 -0.832527  0.019145  0.888316
# Vx      129982.0  0.000887  1.000627  -3.136737 -0.713950  0.010402  0.745366
# Vy      129982.0  0.003002  1.001795  -2.964310 -0.719889 -0.016264  0.719243
# Vz      129982.0  0.001217  1.000030  -4.002201 -0.592784  0.005625  0.590960
# x_sim   129982.0 -0.001650  0.997447 -10.002493 -0.483600  0.011332  0.477304
# y_sim   129982.0  0.000919  1.000829 -11.059974 -0.467484  0.011119  0.476295
# z_sim   129982.0 -0.000651  0.999315  -8.628536 -0.380103  0.006436  0.399140
# Vx_sim  129982.0  0.001130  1.002003  -3.126207 -0.718826  0.011815  0.743078
# Vy_sim  129982.0  0.004858  1.001302  -3.209618 -0.719916  0.000971  0.722968
# Vz_sim  129982.0 -0.000335  0.999210  -3.624755 -0.589240  0.006347  0.585358
#
#              max
# sat_id  1.693320
# Vx      3.085047
# Vy      3.227379
# Vz      4.077451
# x_sim   7.940276
# y_sim   8.154777
# z_sim   9.581585
# Vx_sim  2.819324
# Vy_sim  3.079462
# Vz_sim  4.088883

# %%
print(normed_test_data.shape)
normed_test_data.head()
# Out:
# (129982, 10)
#       sat_id        Vx        Vy        Vz     x_sim     y_sim     z_sim  \
# id
# 1  -1.800866 -0.114280 -1.645301 -0.289286 -0.378704  0.051925 -1.180214
# 4  -1.800866  0.376527 -0.970127  1.108244 -0.227991 -1.141345 -0.721564
# 15 -1.800866 -0.039154  1.022432 -0.139231  0.716221 -0.091263  1.936827
# 22 -1.800866 -0.590838 -0.508568 -1.690348 -0.020474  1.082138 -0.187834
# 26 -1.800866  0.104692 -1.559217  0.340167 -0.379433 -0.408845 -1.170397
#
#       Vx_sim    Vy_sim    Vz_sim
# id
# 1  -0.114772 -1.641642 -0.291518
# 4   0.375696 -0.969551  1.107991
# 15 -0.038963  1.022244 -0.139380
# 22 -0.590174 -0.508629 -1.692253
# 26  0.104497 -1.555827  0.340110

# %%
def create_model(input_dim):
    NN_model = Sequential()

    # The Input Layer :
    NN_model.add(Dense(128, kernel_initializer='normal',input_dim = input_dim, activation='relu'))

    # The Hidden Layers :
    NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
    NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
    NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
    NN_model.summary()
    return NN_model

# %%
list_variable
# Out:
# {'x': ['sat_id', 'x_sim', 'y_sim', 'Vz_sim'],
#  'y': ['sat_id', 'x_sim', 'y_sim', 'Vx_sim'],
#  'z': ['sat_id', 'y_sim', 'z_sim', 'Vy_sim']}

# %%
train_labels.head()
# Out:
#                     x             y             z
# id
# 162906  -22445.306373   5848.139687    805.906588
# 123662   -9086.781838   7654.307240  -6721.299832
# 901720  -33475.100342 -37591.455624  -3269.507831
# 308669   11617.034853   2343.826977  -1821.565305
# 1154759  25113.931453   -473.679010  41867.498593

# %%
test_mydata.head()
# Out:
#     sat_id             x             y             z        Vx        Vy  \
# id
# 1        0 -10567.672384   1619.746066 -24451.813271 -0.302590 -4.272617
# 4        0  -6719.092336 -28929.061629 -14938.907967  0.992507 -2.519732
# 15       0  17281.246143  -2011.121378  39970.739873 -0.104355  2.653343
# 22       0  -1447.724638  28032.228987  -3918.192838 -1.560091 -1.321435
# 26       0 -10583.521489 -10145.003880 -24243.775722  0.275212 -4.049127
#
#           Vz         x_sim         y_sim         z_sim    Vx_sim    Vy_sim  \
# id
# 1  -0.612796 -10555.500066   1649.289367 -24473.089556 -0.303704 -4.269816
# 4   2.344703  -6729.358857 -28902.271436 -14992.399986  0.989382 -2.522618
# 15 -0.295245  17241.395285  -2016.770194  39958.759155 -0.103839  2.655338
# 22 -3.577772  -1461.093061  28026.085525  -3959.767549 -1.557072 -1.324386
# 26  0.719273 -10574.016380 -10147.909472 -24270.149411  0.274385 -4.046727
#
#       Vz_sim
# id
# 1  -0.616468
# 4   2.342237
# 15 -0.294835
# 22 -3.577769
# 26  0.718858

# %%
for i in list_variable:
    train=normed_train_data[list_variable[i]]
    label_train=train_labels[i].values
    print(i, train.columns)
    test=normed_test_data[list_variable[i]]
    label_test=test_labels[i].values
    print(len(train.columns))
    model=create_model(input_dim=len(train.columns))
    model.fit(train, label_train, validation_data=(test, label_test), epochs=10)
    test_mydata[i+'_pred']=model.predict(test)
# Out:
# x Index(['sat_id', 'x_sim', 'y_sim', 'Vz_sim'], dtype='object')
# 4
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 128)               640
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_23 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 165,505
# Trainable params: 165,505
# Non-trainable params: 0
# _________________________________________________________________
# Train on 519930 samples, validate on 129982 samples
# Epoch 1/10
# 519930/519930 [==============================] - 48s 93us/step - loss: 3294.6684 - mean_absolute_error: 3294.6702 - val_loss: 3245.7198 - val_mean_absolute_error: 3245.7205
# Epoch 2/10
# 519930/519930 [==============================] - 47s 91us/step - loss: 3158.4006 - mean_absolute_error: 3158.4131 - val_loss: 3172.7784 - val_mean_absolute_error: 3172.7798
# Epoch 3/10
# 519930/519930 [==============================] - 46s 89us/step - loss: 3146.6615 - mean_absolute_error: 3146.6677 - val_loss: 3107.9322 - val_mean_absolute_error: 3107.9336
# Epoch 4/10
# 519930/519930 [==============================] - 46s 89us/step - loss: 3135.8704 - mean_absolute_error: 3135.8801 - val_loss: 3146.0776 - val_mean_absolute_error: 3146.0789
# Epoch 5/10
# 519930/519930 [==============================] - 46s 89us/step - loss: 3124.0056 - mean_absolute_error: 3123.9968 - val_loss: 3123.6328 - val_mean_absolute_error: 3123.6345
# Epoch 6/10
# 519930/519930 [==============================] - 46s 88us/step - loss: 3114.3510 - mean_absolute_error: 3114.3525 - val_loss: 3146.0970 - val_mean_absolute_error: 3146.0979
# Epoch 7/10
# 519930/519930 [==============================] - 47s 90us/step - loss: 3102.2889 - mean_absolute_error: 3102.2786 - val_loss: 3099.8308 - val_mean_absolute_error: 3099.8306
# Epoch 8/10
# 519930/519930 [==============================] - 46s 89us/step - loss: 3087.9250 - mean_absolute_error: 3087.9211 - val_loss: 3102.3408 - val_mean_absolute_error: 3102.3364
# Epoch 9/10
# 519930/519930 [==============================] - 47s 91us/step - loss: 3071.3617 - mean_absolute_error: 3071.3572 - val_loss: 3040.6739 - val_mean_absolute_error: 3040.6748
# Epoch 10/10
# 519930/519930 [==============================] - 47s 91us/step - loss: 3047.7848 - mean_absolute_error: 3047.7888 - val_loss: 3003.5411 - val_mean_absolute_error: 3003.5396
# y Index(['sat_id', 'x_sim', 'y_sim', 'Vx_sim'], dtype='object')
# 4
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 128)               640
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 165,505
# Trainable params: 165,505
# Non-trainable params: 0
# _________________________________________________________________
# Train on 519930 samples, validate on 129982 samples
# Epoch 1/10
# 519930/519930 [==============================] - 50s 97us/step - loss: 3287.4028 - mean_absolute_error: 3287.4155 - val_loss: 3185.7607 - val_mean_absolute_error: 3185.7581
# Epoch 2/10
# 519930/519930 [==============================] - 49s 95us/step - loss: 3161.0685 - mean_absolute_error: 3161.0708 - val_loss: 3188.4747 - val_mean_absolute_error: 3188.4744
# Epoch 3/10
# 519930/519930 [==============================] - 49s 94us/step - loss: 3147.7614 - mean_absolute_error: 3147.7637 - val_loss: 3163.7865 - val_mean_absolute_error: 3163.7896
# Epoch 4/10
# 519930/519930 [==============================] - 49s 95us/step - loss: 3139.3400 - mean_absolute_error: 3139.3474 - val_loss: 3294.4755 - val_mean_absolute_error: 3294.4717
# Epoch 5/10
# 519930/519930 [==============================] - 49s 94us/step - loss: 3134.5728 - mean_absolute_error: 3134.5732 - val_loss: 3137.0554 - val_mean_absolute_error: 3137.0576
# Epoch 6/10
# 519930/519930 [==============================] - 50s 96us/step - loss: 3123.9117 - mean_absolute_error: 3123.9165 - val_loss: 3127.0904 - val_mean_absolute_error: 3127.0881
# Epoch 7/10
# 519930/519930 [==============================] - 50s 96us/step - loss: 3113.8479 - mean_absolute_error: 3113.8418 - val_loss: 3113.1014 - val_mean_absolute_error: 3113.1021
# Epoch 8/10
# 519930/519930 [==============================] - 49s 95us/step - loss: 3099.9891 - mean_absolute_error: 3099.9885 - val_loss: 3262.5740 - val_mean_absolute_error: 3262.5742
# Epoch 9/10
# 519930/519930 [==============================] - 51s 97us/step - loss: 3082.7359 - mean_absolute_error: 3082.7334 - val_loss: 3086.4292 - val_mean_absolute_error: 3086.4402
# Epoch 10/10
# 519930/519930 [==============================] - 51s 98us/step - loss: 3062.1278 - mean_absolute_error: 3062.1255 - val_loss: 3042.9755 - val_mean_absolute_error: 3042.9749
# z Index(['sat_id', 'y_sim', 'z_sim', 'Vy_sim'], dtype='object')
# 4
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 128)               640
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_34 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 165,505
# Trainable params: 165,505
# Non-trainable params: 0
# _________________________________________________________________
# Train on 519930 samples, validate on 129982 samples
# Epoch 1/10
# 519930/519930 [==============================] - 49s 95us/step - loss: 2478.0648 - mean_absolute_error: 2478.0581 - val_loss: 2345.8124 - val_mean_absolute_error: 2345.8123
# Epoch 2/10
# 519930/519930 [==============================] - 54s 104us/step - loss: 2376.6699 - mean_absolute_error: 2376.6816 - val_loss: 2324.4875 - val_mean_absolute_error: 2324.4883
# Epoch 3/10
# 519930/519930 [==============================] - 47s 91us/step - loss: 2371.2205 - mean_absolute_error: 2371.2231 - val_loss: 2327.6704 - val_mean_absolute_error: 2327.6682
# Epoch 4/10
# 519930/519930 [==============================] - 48s 93us/step - loss: 2362.6139 - mean_absolute_error: 2362.6111 - val_loss: 2400.6485 - val_mean_absolute_error: 2400.6409
# Epoch 5/10
# 519930/519930 [==============================] - 48s 93us/step - loss: 2356.3932 - mean_absolute_error: 2356.3938 - val_loss: 2333.9647 - val_mean_absolute_error: 2333.9631
# Epoch 6/10
# 519930/519930 [==============================] - 55s 105us/step - loss: 2350.5908 - mean_absolute_error: 2350.5930 - val_loss: 2334.1326 - val_mean_absolute_error: 2334.1353
# Epoch 7/10
# 519930/519930 [==============================] - 50s 96us/step - loss: 2340.6057 - mean_absolute_error: 2340.6045 - val_loss: 2325.4124 - val_mean_absolute_error: 2325.4136
# Epoch 8/10
# 519930/519930 [==============================] - 45s 87us/step - loss: 2326.5732 - mean_absolute_error: 2326.5696 - val_loss: 2305.6652 - val_mean_absolute_error: 2305.6636
# Epoch 9/10
# 519930/519930 [==============================] - 45s 87us/step - loss: 2311.1451 - mean_absolute_error: 2311.1475 - val_loss: 2269.0971 - val_mean_absolute_error: 2269.0984
# Epoch 10/10
# 519930/519930 [==============================] - 45s 87us/step - loss: 2296.0365 - mean_absolute_error: 2296.0417 - val_loss: 2284.1393 - val_mean_absolute_error: 2284.1421

# %%
test_mydata.head()
# Out:
#     sat_id             x             y             z        Vx        Vy  \
# id
# 1        0 -10567.672384   1619.746066 -24451.813271 -0.302590 -4.272617
# 4        0  -6719.092336 -28929.061629 -14938.907967  0.992507 -2.519732
# 15       0  17281.246143  -2011.121378  39970.739873 -0.104355  2.653343
# 22       0  -1447.724638  28032.228987  -3918.192838 -1.560091 -1.321435
# 26       0 -10583.521489 -10145.003880 -24243.775722  0.275212 -4.049127
#
#           Vz         x_sim         y_sim         z_sim    Vx_sim    Vy_sim  \
# id
# 1  -0.612796 -10555.500066   1649.289367 -24473.089556 -0.303704 -4.269816
# 4   2.344703  -6729.358857 -28902.271436 -14992.399986  0.989382 -2.522618
# 15 -0.295245  17241.395285  -2016.770194  39958.759155 -0.103839  2.655338
# 22 -3.577772  -1461.093061  28026.085525  -3959.767549 -1.557072 -1.324386
# 26  0.719273 -10574.016380 -10147.909472 -24270.149411  0.274385 -4.046727
#
#       Vz_sim        x_pred        y_pred        z_pred
# id
# 1  -0.616468  -9183.037109   1851.521240 -24268.890625
# 4   2.342237  -8604.287109 -28910.746094 -15109.281250
# 15 -0.294835  16839.861328  -2926.081055  40413.890625
# 22 -3.577769   1686.144043  27366.716797  -3611.077881
# 26  0.718858 -11038.967773  -9878.979492 -24278.093750

# %%
def smape(satellite_predicted_values, satellite_true_values):
    return np.mean(np.abs((satellite_predicted_values - satellite_true_values)/(np.abs(satellite_predicted_values) + np.abs(satellite_true_values))))

# %%
for i in ['_sim', '_pred']:
    real=test_mydata[label].values
    comp=test_mydata[[j+i for j in label]].values
    print('smape real vs %s : %f'%(i, smape(real, comp)))
# Out:
# smape real vs _sim : 0.184052
# smape real vs _pred : 0.182019
